# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("log.csv")
df
# Out:
#              t   col  puffer_oben  puffer_unten
# 0     10:40:32  47.4         55.7          38.4
# 1     10:40:44  47.4         55.7          38.4
# 2     10:40:58  47.6         55.7          38.4
# 3     10:41:11  47.6         55.7          38.4
# 4     10:41:23  47.8         55.7          38.4
# ...        ...   ...          ...           ...
# 1108  16:53:03  44.2         51.3          43.5
# 1109  16:53:16  44.2         51.3          43.5
# 1110  16:56:42  44.2         51.3          43.5
# 1111  16:56:55  44.1         51.2          43.4
# 1112  16:57:08  44.1         51.2          43.4
#
# [1113 rows x 4 columns]

# %%
#p=df['col'].to_numpy()[:3000]
#len(p)
#p.argmax()
#df.iloc[2350]

# %%
puffer_oben = df['puffer_oben'].to_numpy()
puffer_unten = df['puffer_unten'].to_numpy()
kollektor = df['col'].to_numpy()
t = df['t'].to_numpy()

# %%
# %matplotlib inline 
from matplotlib import pyplot as pl
pl.rcParams["figure.figsize"] = (10,5)
x = range(len(puffer_oben))

# %%
pl.plot(t,puffer_oben,label="po")
pl.plot(t,puffer_unten,label="pu")
pl.plot(t,kollektor,label="col")
pl.xticks(np.arange(min(x), max(x)+1, 100))
pl.gcf().autofmt_xdate()
pl.grid()
pl.legend()
pl.show()

# %%
pl.plot(t,puffer_oben,label="po")
pl.plot(t,puffer_unten,label="pu")
pl.plot(t,kollektor,label="col")
pl.xticks(np.arange(min(x), max(x)+1, 100))
pl.gcf().autofmt_xdate()
pl.grid()
pl.legend()
pl.show()

# %%
pl.plot(t,puffer_oben,label="po")
pl.plot(t,puffer_unten,label="pu")
pl.plot(t,kollektor,label="col")
pl.xticks(np.arange(min(x), max(x)+1, 100))
pl.gcf().autofmt_xdate()
pl.grid()
pl.legend()
pl.show()

# %%
#pl.plot(t,puffer_oben)
#pl.plot(t,puffer_unten)
pl.plot(t,kollektor)
pl.xticks(np.arange(min(x), max(x)+1, 100))
pl.gcf().autofmt_xdate()
pl.grid()
pl.show()
