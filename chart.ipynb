# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("log/log_20221021.csv")
df
# Out:
#              t   col  puffer_oben  puffer_unten
# 0     00:00:08  19.5         57.5          36.5
# 1     00:00:19  19.5         57.5          36.5
# 2     00:00:31  19.5         57.5          36.5
# 3     00:00:43  19.5         57.5          36.5
# 4     00:00:54  19.5         57.5          36.5
# ...        ...   ...          ...           ...
# 3070  10:15:32  23.4         56.3          35.5
# 3071  10:15:43  23.5         56.3          35.5
# 3072  10:15:54  23.6         56.3          35.5
# 3073  10:16:06  23.6         56.3          35.5
# 3074  10:16:17  23.6         56.2          35.5
#
# [3075 rows x 4 columns]

# %%
puffer_oben = df['puffer_oben'].to_numpy()
puffer_unten = df['puffer_unten'].to_numpy()
kollektor = df['col'].to_numpy()
t = df['t'].to_numpy()

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as pl
pl.rcParams["figure.figsize"] = (10,5)
x = range(len(puffer_oben))

# %%
pl.plot(t,puffer_oben,label="po")
pl.plot(t,puffer_unten,label="pu")
pl.plot(t,kollektor,label="col")
pl.xticks(np.arange(min(x), max(x)+1, 100))
pl.gcf().autofmt_xdate()
pl.grid()
pl.legend()
pl.show()

# %%
#pl.plot(t,puffer_oben)
#pl.plot(t,puffer_unten)
pl.plot(t,kollektor)
pl.xticks(np.arange(min(x), max(x)+1, 100))
pl.gcf().autofmt_xdate()
pl.grid()
pl.show()
